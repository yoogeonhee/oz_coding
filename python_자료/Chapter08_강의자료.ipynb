# %%
상자 = {"아디다스": ["신발", "2개"], "나이키": ["모자", "5개"], "뉴발란스": ["가방", "1개"]}

# %%
상자["칼하트"] = ["후드티", "2벌"]

# %%
상자
# Out:
# {'아디다스': ['신발', '2개'],
#  '나이키': ['모자', '5개'],
#  '뉴발란스': ['가방', '1개'],
#  '칼하트': ['후드티', '2벌']}

# %%
money = { '만원', '만원', '오만원', '백원', '오만원', '십원' }

# %%
money
# Out:
# {'만원', '백원', '십원', '오만원'}
