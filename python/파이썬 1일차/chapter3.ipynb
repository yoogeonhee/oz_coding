# %%
# 주석은 이렇게 하는거다.
print("진짜 안보이는거야?")
#print("신기한데?")
# Out:
# 진짜 안보이는거야?

# %%
for 동물 in ("토끼", "사자", "푸바오", "호랑이"):
    print(동물)
    print("보러갈래요?")
# Out:
# 토끼
# 보러갈래요?
# 사자
# 보러갈래요?
# 푸바오
# 보러갈래요?
# 호랑이
# 보러갈래요?
